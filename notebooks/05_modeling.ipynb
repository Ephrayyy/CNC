# %% [markdown]
# # 05 - Modeling
#
# Ce notebook entraîne le modèle, compare les candidats et charge les métriques sauvegardées.

# %%
from pathlib import Path
import sys
import json
import joblib

ROOT_DIR = Path.cwd()
if ROOT_DIR.name == 'notebooks':
    ROOT_DIR = ROOT_DIR.parent

if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from src.models.train_model import train_model, MODEL_PATH, METRICS_PATH

# %%
metrics = train_model()
metrics

# %%
with METRICS_PATH.open('r', encoding='utf-8') as stream:
    saved_metrics = json.load(stream)

saved_metrics

# %%
artifact = joblib.load(MODEL_PATH)
artifact.keys()

# %%
artifact['model_name']
